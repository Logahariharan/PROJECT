# %% [markdown]
# # Default of credit card clients

# %% [markdown]
# NAME :LOGA HARIHARAN VG

# %% [markdown]
# **PROBLEM STATEMENT**

# %% [markdown]
# Develop a machine learning model to predict whether a credit card client will default on their payment next month based on their financial and demographic data.

# %% [markdown]
# **Objective:**
#
# Predict the likelihood of a credit card client defaulting on their next month’s payment.
#
# Analyze key financial and demographic factors influencing default risk.
#
# Build and train a machine learning classification model using historical data.
#
# Evaluate model performance using accuracy, precision, recall, and F1 score.
#
# Provide actionable insights to help financial institutions manage credit risk

# %% [markdown]
# ![images.jfif](data:image/jpeg;base64,...)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
data=pd.read_csv('/content/default of credit card clients (2) (1).csv')

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df.head(10)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
# 5   6      50000    1          1         2   37      0      0      0      0
# 6   7     500000    1          1         2   29      0      0      0      0
# 7   8     100000    2          2         2   23      0     -1     -1      0
# 8   9     140000    2          3         1   28      0      0      2      0
# 9  10      20000    1          3         2   35     -2     -2     -2     -2
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df.dropna()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
y=df['default payment next month']

# %%
x=df.drop('default payment next month',axis=1)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.shape
# Out:
# (30000, 25)

# %% [markdown]
# HANDLING OUTLIERS

# %%
num_columns = data.select_dtypes(include='number')
num_columns.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
for column in num_columns:
  sns.boxplot(data= num_columns,x=column)
  plt.show()

# %%
def handling_outliers(df1):
  for col in df.select_dtypes(include=np.number):
    Q1=df1[col].quantile(0.25)
    Q3=df1[col].quantile(0.75)
    IQR=Q3-Q1
    Lower_bound=Q1-(1.5*IQR)
    Upper_bound=Q3+(1.5*IQR)
    df[col]=df[col.apply(lambda x: lower_bound if x<lower_bound else Upper_bound if x>upper_bound else x)]
  return df1

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, y='SEX', x='AGE')
plt.title('SEX VS AGE')
plt.xlabel('SEX')
plt.ylabel('AGE')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.lineplot(data=df, x='EDUCATION', y='MARRIAGE', marker='o')
plt.title('EDUCATION VS MARRIAGE')
plt.xlabel('EDUCATION')
plt.ylabel('MARRIAGE')
plt.tight_layout()
plt.show()
plt.ylabel('MARRIAGE')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='PAY_0', bins=20, kde=True, color='skyblue')
plt.title('PAY_0')
plt.xlabel('PAY')
plt.ylabel('PAYMENT')
plt.tight_layout()
plt.show()

# %%
#KDE plot
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='PAY_0', fill=True, color='Red')
plt.title('PAY_0')
plt.xlabel('PAY')
plt.ylabel('AMOUNT')
plt.tight_layout()
plt.show()

# %%
a=df.corr()
a
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(a,cmap='coolwarm',linewidth=0.5,fmt='.2f')
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
#violin plot
plt.figure(figsize=(8,6))
sns.violinplot(x='PAY_0',y='PAY_2',data=df)
plt.title('PAY_0 VS PAY_2')
plt.xlabel('PAY_0')
plt.ylabel('PAY_2')
# Out:
# Text(0, 0.5, 'PAY_2')

# %%
df.skew()
# Out:
# ID                             0.000000
# LIMIT_BAL                      0.992867
# SEX                           -0.424183
# EDUCATION                      0.970972
# MARRIAGE                      -0.018742
# AGE                            0.732246
# PAY_0                          0.731975
# PAY_2                          0.790565
# PAY_3                          0.840682
# PAY_4                          0.999629
# PAY_5                          1.008197
# PAY_6                          0.948029
# BILL_AMT1                      2.663861
# BILL_AMT2                      2.705221
# BILL_AMT3                      3.087830
# BILL_AMT4                      2.821965
# BILL_AMT5                      2.876380
# BILL_AMT6                      2.846645
# PAY_AMT1                      14.668364
# PAY_AMT2                      30.453817
# PAY_AMT3                      17.216635
# PAY_AMT4                      12.904985
# PAY_AMT5                      11.127417
# ...

# %%
X=df.drop(columns='EDUCATION',axis=1)
y=df['EDUCATION']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# %%
selecter=SelectKBest(score_func=f_regression,k=70)
X_new=selecter.fit_transform(X,y)
Selected_features=X.columns[selecter.get_support()]
feature_score=pd.DataFrame({'Feature':X.columns,'Score':selecter.scores_}).sort_values(by='Score',ascending=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=70 is greater than n_features=24. All the features will be returned.
#   warnings.warn(

# %%
print(feature_score)
# Out:
#                        Feature        Score
# 1                    LIMIT_BAL  1513.543939
# 4                          AGE   948.390358
# 3                     MARRIAGE   630.394128
# 6                        PAY_2   449.965625
# 7                        PAY_3   395.162122
# 8                        PAY_4   359.309605
# 5                        PAY_0   336.763564
# 9                        PAY_5   288.025607
# 10                       PAY_6   204.650794
# 21                    PAY_AMT5    48.940604
# 19                    PAY_AMT3    47.936925
# 0                           ID    46.112201
# 20                    PAY_AMT4    43.880018
# 17                    PAY_AMT1    42.145294
# 22                    PAY_AMT6    41.569742
# 18                    PAY_AMT2    27.091419
# 23  default payment next month    23.547112
# 11                   BILL_AMT1    16.690331
# 12                   BILL_AMT2    10.548497
# 2                          SEX     6.077266
# ...

# %%
X_Selected=X[Selected_features]

# %%
X_Selected.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3',
#        'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3',
#        'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2',
#        'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_Selected,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
Ss=StandardScaler()
X_train_scaled=Ss.fit_transform(X_train)
X_test_scaled=Ss.fit_transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

# %%
models={'Linear Regression':LinearRegression(),
        'Random Forest':RandomForestRegressor(random_state=42),
        'Support Vector Machine':SVR(),
        'Decision Tree':DecisionTreeRegressor()}

# %%
results={}
for name,model in models.items():
  model.fit(X_train_scaled,y_train)
  y_pred=model.predict(X_test_scaled)
  results[name]={'MSE':mean_squared_error(y_test,y_pred),
                 'MAE':mean_absolute_error(y_test,y_pred),
                 'R2':r2_score(y_test,y_pred)}

# %%
print("\nModel Performance:")
for model_name,metrics in results.items():
  print(f"{model_name}:")
  for metric_name,value in metrics.items():
    print(f"{metric_name}:{value:.4f}")
# Out:
# Model Performance:
# Linear Regression:
# MSE:0.5415
# MAE:0.5592
# R2:0.1168
# Random Forest:
# MSE:0.5447
# MAE:0.5721
# R2:0.1114
# Support Vector Machine:
# MSE:0.5530
# MAE:0.5390
# R2:0.0979
# Decision Tree:
# MSE:1.2385
# MAE:0.7648
# R2:-1.0202
